# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from matplotlib import pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import nltk
import seaborn as sns
import lightgbm as lgb
from nltk.corpus import stopwords
import matplotlib as mpl
nltk.download("stopwords") 
import re


pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
#pd.set_option('display.max_colwidth', -1)  # or 199
pd.set_option('display.expand_frame_repr', False)

# Prepare Positive Set
df_users = pd.read_csv(r'D:\vanhack\data\HiredCandidates.csv').reset_index(drop=True)
df_users = df_users.rename(columns={'Skills':'UserSkills'})

df_jobs = pd.read_csv(r'D:\vanhack\data\HiredJobDetails.csv').reset_index(drop=True)
df_jobs = df_jobs.rename(columns={'POSITION':'JobsPosition','Skills':'JobSkills','Responsibilities':'JobResponsibilities'})

cols_to_use = df_jobs.columns.difference(df_users.columns)

df = pd.merge(df_users,df_jobs[cols_to_use],left_on=['HiredForJobId'],right_on=['JobId'],how='inner')
df['hired'] = 1

df.columns = df.columns.str.lower()
df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anish\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    userid  hiredforjobid                                         userskills             usersposition  jobid                                jobresponsibilities                                          jobskills                 jobsposition  hired
# 0  533441           1357  django, docker, typescript, flask, numpy, pand...    Senior Developer / CTO   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...                          javascript, ruby on rails   Lead BackEnd RoR Developer      1
# 1  696183           1357  ruby on rails, javascript, python, java, html,...         Software Engineer   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...                          javascript, ruby on rails   Lead BackEnd RoR Developer      1
# 2  696873           1357  c++, erlang, linux kernel, tcp/ip, web develop...  Senior Software Engineer   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...                          javascript, ruby on rails   Lead BackEnd RoR Developer      1
# 3  634908           1265  oop, nosql, agile, agile development methodolo...      Full Stack Developer   1265  <p><strong>The ideal candidate:</strong><br>\n...  agile, aws, continuous integration, java, java...  Senior Full Stack Developer      1
# 4  635261           1590  fast learning, strong communication skills, gi...          Mobile Developer   1590  <ul>\n  <li>4+ years experience in a related f...  angular, cloud computing, javascript, kubernet...    Senior Software Developer      1

# %%
# Prepare Negative Set - Simple random selection

df_available = pd.read_csv(r'D:\vanhack\data\AvailableCandidates.csv')
df_available['hired'] = 0
df_available = df_available.sample(n=df.shape[0],random_state=2).reset_index(drop=True)
df_available = df_available.rename(columns={'Skills':'UserSkills'})
df_available.columns = df_available.columns.str.lower()
df_available = df_available[['userid','userskills','usersposition','hired']]

df_jobs = df[['jobid','jobresponsibilities','jobsposition','jobskills']].reset_index(drop=True)

df_neg = pd.concat([df_available,df_jobs],axis=1)

df = df[df_neg.columns.values]
df = pd.concat([df,df_neg])

# %%
# complete set
print(df.shape)
df.head()
# Out:
# (404, 8)
#    userid                                         userskills             usersposition  hired  jobid                                jobresponsibilities                 jobsposition                                          jobskills
# 0  533441  django, docker, typescript, flask, numpy, pand...    Senior Developer / CTO      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails
# 1  696183  ruby on rails, javascript, python, java, html,...         Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails
# 2  696873  c++, erlang, linux kernel, tcp/ip, web develop...  Senior Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails
# 3  634908  oop, nosql, agile, agile development methodolo...      Full Stack Developer      1   1265  <p><strong>The ideal candidate:</strong><br>\n...  Senior Full Stack Developer  agile, aws, continuous integration, java, java...
# 4  635261  fast learning, strong communication skills, gi...          Mobile Developer      1   1590  <ul>\n  <li>4+ years experience in a related f...    Senior Software Developer  angular, cloud computing, javascript, kubernet...

# %%
# Engineer Features

def create_features(row):
    
    def cleanhtml(raw_html):
        cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
        cleantext = re.sub(cleanr, '', raw_html)
        return cleantext

    user_skills = str(row['userskills']).split(',')
    job_skills = str(row['jobskills']).split(',')
    resp_skills = str(row['jobresponsibilities']).split(' ')

    user_skills = [x.strip(' ') for x in user_skills]
    job_skills = [x.strip(' ') for x in job_skills]

    #resp_skills = cleanhtml(resp_skills).split(' ')

    #filtered_words = [word for word in resp_skills if word not in stopwords.words('english')]
    #best_match = process.extractOne(search_name, np.delete(all_values,idx) ,scorer=fuzz.token_sort_ratio)

    common_skills = []
    common_resp_skills = []
    other_skills = []

    for skill in user_skills:
        skill = skill.strip()
        if skill in job_skills:
            common_skills.append(skill)
        else:
            other_skills.append(skill)
            
        if skill in resp_skills:
            common_resp_skills.append(skill)        
            
    row['userskills_no'] = len(user_skills)
    row['jobskills_no'] = len(job_skills)
    row['common_skills'] = len(common_skills)
    row['common_skills_text'] = common_skills
    row['common_resp_skills'] = common_resp_skills


    row['common_skills_ratio'] = (len(common_skills)/len(job_skills)) # 1 is ideal
    row['other_skills_ratio'] = (len(other_skills)/len(user_skills)) # 0 is ideal
    row['job_candiate_skill_ratio'] = (len(job_skills)/len(user_skills)) # 1 is ideal

    #row['position_match'] = process.extractOne(str(row['user_UsersPosition']), str(row['job_POSITION']) ,scorer=fuzz.token_sort_ratio)[1]
    row['position_match'] = fuzz.token_sort_ratio(str(row['usersposition']), str(row['jobsposition']))
        
    #     score                  feature
    #        4            position_match
    #        3       common_skills_ratio
    #        3             userskills_no
    #        2  job_candiate_skill_ratio
    #        1        other_skills_ratio

    #row['match_score'] = 4*row['position_match'] + 7*row['common_skills_ratio']*100
          
    return row


df = df.apply(create_features,axis=1)
#df = df.sort_values(by='position_match',ascending=False)
df.head()
# Out:
#    userid                                         userskills             usersposition  hired  jobid                                jobresponsibilities                 jobsposition                                          jobskills  userskills_no  jobskills_no  common_skills                                 common_skills_text common_resp_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match
# 0  533441  django, docker, typescript, flask, numpy, pand...    Senior Developer / CTO      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails             23             2              0                                                 []                 []             0.000000            1.000000                  0.086957              65
# 1  696183  ruby on rails, javascript, python, java, html,...         Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails             15             2              2                        [ruby on rails, javascript]                 []             1.000000            0.866667                  0.133333              37
# 2  696873  c++, erlang, linux kernel, tcp/ip, web develop...  Senior Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails             21             2              1                                       [javascript]                 []             0.500000            0.952381                  0.095238              40
# 3  634908  oop, nosql, agile, agile development methodolo...      Full Stack Developer      1   1265  <p><strong>The ideal candidate:</strong><br>\n...  Senior Full Stack Developer  agile, aws, continuous integration, java, java...             40             9              8  [agile, continuous integration, node.js, java,...                 []             0.888889            0.800000                  0.225000              85
# 4  635261  fast learning, strong communication skills, gi...          Mobile Developer      1   1590  <ul>\n  <li>4+ years experience in a related f...    Senior Software Developer  angular, cloud computing, javascript, kubernet...             15             8              1                                       [javascript]                 []             0.125000            0.933333                  0.533333              59

# %%
# Viz engineered features

plot_cols = df.columns.difference(['userid','userskills','usersposition','hired',
                                   'common_skills_text','common_resp_skills','jobid','jobresponsibilities','jobsposition','jobskills'])
plot_cols = []

for idx,col in enumerate(plot_cols):
    print(col)
    df_hired = df[df['hired'] == 1]
    print(df_hired.shape)
    df_hired[col].plot.hist()
    plt.show()
    
    df_nothired = df[df['hired'] == 0]
    df_nothired[col].plot.hist()
    plt.show()

# %%
# Model a simple binary classification to find the optimum weights and select features

isDebug = False


features = [ 'userskills_no','jobskills_no','common_skills','common_skills_ratio','other_skills_ratio',
            'job_candiate_skill_ratio','position_match','hired']

features = [ 'userskills_no','common_skills_ratio','other_skills_ratio',
            'job_candiate_skill_ratio','position_match','hired']

df[features] = preprocessing.MinMaxScaler().fit_transform(df[features])

print('Modeling binary classification with columns', features)

df_model = df.copy()
df_model = df_model[features]

y = pd.DataFrame(df_model['hired'])
X = df_model.loc[:, df_model.columns != 'hired']
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 if isDebug else 0.0049, random_state=42)

print('Training with {} and testing with {}'.format(X_train.shape[0],X_test.shape[0]))
train_dataset = lgb.Dataset(X_train, label=y_train)
test_dataset = lgb.Dataset(X_test, label=y_test)
    
np.random.seed(0)
nrounds = 100
params = {
    'objective': 'xentropy',
    'metric': "auc",
    'feature_fraction': 1,
    'bagging_fraction': 1,
    'early_stopping_rounds': 100,
    'verbose': -1
}
gbm = lgb.train(params, train_dataset,valid_sets=[test_dataset], num_boost_round=nrounds)


def plot_imp(model, X):
    feature_imp = pd.DataFrame(sorted(zip(model.feature_importance(),X.columns)),columns=['score','feature'])
    feature_imp = feature_imp.sort_values(by='score',ascending=False)
    
    print(feature_imp)

    # Plot the total crashes
    sns.set_color_codes("pastel")
    sns.barplot(x="score", y="feature",data=feature_imp.head(50),palette=mpl.cm.ScalarMappable(cmap='viridis_r').to_rgba((feature_imp["score"])))
    plt.xlabel("LGBM Importance score")
    plt.ylabel("Feature")
    plt.title("Feature Importance")

    # sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
    # plt.title('LightGBM Important Features')
    # plt.tight_layout()

plot_imp(gbm,X)
plt.show()
# Out:
# Modeling binary classification with columns ['userskills_no', 'common_skills_ratio', 'other_skills_ratio', 'job_candiate_skill_ratio', 'position_match', 'hired']
# Training with 402 and testing with 2
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# [11]	valid_0's auc: 1
# [12]	valid_0's auc: 1
# [13]	valid_0's auc: 1
# [14]	valid_0's auc: 1
# [15]	valid_0's auc: 1
# [16]	valid_0's auc: 1
# [17]	valid_0's auc: 1
# [18]	valid_0's auc: 1
# [19]	valid_0's auc: 1
# [20]	valid_0's auc: 1
# [21]	valid_0's auc: 1
# [22]	valid_0's auc: 1
# [23]	valid_0's auc: 1
# [24]	valid_0's auc: 1
# [25]	valid_0's auc: 1
# [26]	valid_0's auc: 1
# [27]	valid_0's auc: 1
# [28]	valid_0's auc: 1
# [29]	valid_0's auc: 1
# [30]	valid_0's auc: 1
# [31]	valid_0's auc: 1
# [32]	valid_0's auc: 1
# [33]	valid_0's auc: 1
# [34]	valid_0's auc: 1
# [35]	valid_0's auc: 1
# [36]	valid_0's auc: 1
# [37]	valid_0's auc: 1
# [38]	valid_0's auc: 1
# [39]	valid_0's auc: 1
# [40]	valid_0's auc: 1
# [41]	valid_0's auc: 1
# [42]	valid_0's auc: 1
# [43]	valid_0's auc: 1
# [44]	valid_0's auc: 1
# [45]	valid_0's auc: 1
# [46]	valid_0's auc: 1
# [47]	valid_0's auc: 1
# [48]	valid_0's auc: 1
# [49]	valid_0's auc: 1
# [50]	valid_0's auc: 1
# [51]	valid_0's auc: 1
# [52]	valid_0's auc: 1
# [53]	valid_0's auc: 1
# [54]	valid_0's auc: 1
# [55]	valid_0's auc: 1
# [56]	valid_0's auc: 1
# [57]	valid_0's auc: 1
# [58]	valid_0's auc: 1
# [59]	valid_0's auc: 1
# [60]	valid_0's auc: 1
# [61]	valid_0's auc: 1
# [62]	valid_0's auc: 1
# [63]	valid_0's auc: 1
# [64]	valid_0's auc: 1
# [65]	valid_0's auc: 1
# [66]	valid_0's auc: 1
# [67]	valid_0's auc: 1
# [68]	valid_0's auc: 1
# [69]	valid_0's auc: 1
# [70]	valid_0's auc: 1
# [71]	valid_0's auc: 1
# [72]	valid_0's auc: 1
# [73]	valid_0's auc: 1
# [74]	valid_0's auc: 1
# [75]	valid_0's auc: 1
# [76]	valid_0's auc: 1
# [77]	valid_0's auc: 1
# [78]	valid_0's auc: 1
# [79]	valid_0's auc: 1
# [80]	valid_0's auc: 1
# [81]	valid_0's auc: 1
# [82]	valid_0's auc: 1
# [83]	valid_0's auc: 1
# [84]	valid_0's auc: 1
# [85]	valid_0's auc: 1
# [86]	valid_0's auc: 1
# [87]	valid_0's auc: 1
# [88]	valid_0's auc: 1
# [89]	valid_0's auc: 1
# [90]	valid_0's auc: 1
# [91]	valid_0's auc: 1
# [92]	valid_0's auc: 1
# [93]	valid_0's auc: 1
# [94]	valid_0's auc: 1
# [95]	valid_0's auc: 1
# [96]	valid_0's auc: 1
# [97]	valid_0's auc: 1
# [98]	valid_0's auc: 1
# [99]	valid_0's auc: 1
# [100]	valid_0's auc: 1
# Did not meet early stopping. Best iteration is:
# [1]	valid_0's auc: 1
#    score                   feature
# 1      3       common_skills_ratio
# 2      3  job_candiate_skill_ratio
# 3      3            position_match
# 4      3             userskills_no
# 0      1        other_skills_ratio
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
# Generate predictions dataset - create df with each job for all available candidates

df_test =  pd.read_csv(r'D:\vanhack\data\JobsToPredict.csv')
df_test = df_test.rename(columns={'POSITION':'JobsPosition','Skills':'JobSkills','Responsibilities':'JobResponsibilities'})
df_test.columns = df_test.columns.str.lower()

df_available = pd.read_csv(r'D:\vanhack\data\AvailableCandidates.csv')
#df_available = pd.read_csv(r'E:\Projects\PycharmProjects\Vanhack\data\SmallCandidates.csv')
df_available = df_available.rename(columns={'Skills':'UserSkills'})
df_available.columns = df_available.columns.str.lower()
df_available = df_available[['userid','userskills','usersposition']]
df_available = df_available.reset_index(drop=True)

# Predict for each job with all candidates to get top 10 candidates

njobs = df_test.shape[0]
ncandidates = df_available.shape[0]

df_pred = df_test.iloc[[4]]
df_pred = df_pred.append([df_pred]*ncandidates,ignore_index=True)
df_pred = df_pred.reset_index(drop=True)

print(df_pred.shape)
df_pred.head()
# Out:
# (10001, 4)
#    jobid                                jobresponsibilities                     jobsposition                                          jobskills
# 0   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...
# 1   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...
# 2   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...
# 3   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...
# 4   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...

# %%
# Generate predictions dataset - concat df with available candidates

print(df_available.columns.values,df_available.shape)
print(df_pred.columns.values,df_pred.shape)
df_pred = pd.concat([df_available,df_pred],axis=1)

df_pred = df_pred.apply(create_features,axis=1)
df_pred['match_score'] = 4*df_pred['position_match'] + 4*df_pred['common_skills_ratio']*100 + 3*df_pred['userskills_no']+ 2*df_pred['job_candiate_skill_ratio'] + df_pred['other_skills_ratio']

df_pred.head()
# Out:
# ['userid' 'userskills' 'usersposition'] (10000, 3)
# ['jobid' 'jobresponsibilities' 'jobsposition' 'jobskills'] (10001, 4)
#      userid                                         userskills                           usersposition  jobid                                jobresponsibilities                     jobsposition                                          jobskills  userskills_no  jobskills_no  common_skills          common_skills_text common_resp_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match  match_score
# 0  533334.0  game maker 1.4, lua, fabric8, h264 encoding, t...                       Software Engineer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...              5             7              0                          []                 []             0.000000            1.000000                  1.400000              39   174.800000
# 1  533339.0  ruby on rails, sql server, javascript, html5, ...                Web Developer Fullstack    2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             15             7              2  [javascript, react native]                 []             0.285714            0.866667                  0.466667              54   377.085714
# 2  533343.0  ruby on rails, scrum, javascript, wordpress, h...      Full stack Ruby on Rails developer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             53             7              1                [javascript]                 []             0.142857            0.981132                  0.132075              60   457.388140
# 3  533344.0  javascript, spring, jsp, hibernate, jpa, servl...        Results-driven Software Engineer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             13             7              1                [javascript]                 []             0.142857            0.923077                  0.538462              39   254.142857
# 4  533348.0  2d, ux, ilustrator, art direction, logo design...  UI/UX Designer & Digital Visual Design   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             11             7              0                          []                 []             0.000000            1.000000                  0.636364              37   183.272727

# %%
# Calculate match score with learnt weights

df_pred['match_score'] = 4*df_pred['position_match'] + 4*df_pred['common_skills_ratio']*100 +3*df_pred['userskills_no']+ 2*df_pred['job_candiate_skill_ratio'] + df_pred['other_skills_ratio']
df_pred.head()
# Out:
#      userid                                         userskills                           usersposition  jobid                                jobresponsibilities                     jobsposition                                          jobskills  userskills_no  jobskills_no  common_skills          common_skills_text common_resp_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match  match_score
# 0  533334.0  game maker 1.4, lua, fabric8, h264 encoding, t...                       Software Engineer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...              5             7              0                          []                 []             0.000000            1.000000                  1.400000              39   174.800000
# 1  533339.0  ruby on rails, sql server, javascript, html5, ...                Web Developer Fullstack    2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             15             7              2  [javascript, react native]                 []             0.285714            0.866667                  0.466667              54   377.085714
# 2  533343.0  ruby on rails, scrum, javascript, wordpress, h...      Full stack Ruby on Rails developer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             53             7              1                [javascript]                 []             0.142857            0.981132                  0.132075              60   457.388140
# 3  533344.0  javascript, spring, jsp, hibernate, jpa, servl...        Results-driven Software Engineer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             13             7              1                [javascript]                 []             0.142857            0.923077                  0.538462              39   254.142857
# 4  533348.0  2d, ux, ilustrator, art direction, logo design...  UI/UX Designer & Digital Visual Design   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...             11             7              0                          []                 []             0.000000            1.000000                  0.636364              37   183.272727

# %%
# Generate predictions
print(features)
cols = list(set(features) - set(['hired']))
df_pred[cols] = preprocessing.MinMaxScaler().fit_transform(df_pred[cols])
df_pred['pred'] = gbm.predict(df_pred[cols])
df_pred = df_pred.sort_values(by='match_score',ascending=False)
df_pred.head(10)

df_pred['pred'].plot.hist()
plt.show()

print(df_pred['pred'].value_counts())

#df_pred = df_pred[['usersposition','jobsposition','pred']]
df_pred.head()
# Out:
# ['userskills_no', 'common_skills_ratio', 'other_skills_ratio', 'job_candiate_skill_ratio', 'position_match', 'hired']
# 0.477792    7800
# 0.509999    1903
# 0.511763     286
# 0.542490       8
# 0.544879       2
# 0.481826       1
# 0.526446       1
# Name: pred, dtype: int64
#         userid                                         userskills                                      usersposition  jobid                                jobresponsibilities                     jobsposition                                          jobskills  userskills_no  jobskills_no  common_skills                                 common_skills_text common_resp_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match  match_score      pred
# 3072  650088.0  android, sql, sql server, scrum, javascript, w...                               Full stack developer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...       0.695652             7              5  [javascript, jenkins, typescript, gradle, reac...                 []                  1.0            0.948454                  0.003138            0.61   821.807069  0.477792
# 5479  664882.0  android, azure, sql, sql server, scrum, javasc...                        Senior Mobile App Developer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...       0.471014             7              5  [javascript, jenkins, typescript, xcode, react...                 []                  1.0            0.924242                  0.008015            0.71   768.850649  0.477792
# 9291  679605.0  tdd, ddd, sql, ruby on rails, sql server, wind...                                  Software Engineer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...       0.956522             7              3                      [javascript, jenkins, gradle]                 []                  0.6            0.977444                  0.000327            0.39   727.511278  0.477792
# 8637  677297.0  scrum, javascript, python, wordpress, english,...                               JavaScript Developer   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...       0.717391             7              3             [javascript, typescript, react native]                 []                  0.6            0.970000                  0.002826            0.61   716.538571  0.477792
# 9869  681538.0  android, tdd, sql, scrum, javascript, python, ...  Senior Full-Stack Developer|Machine/Deep Learn...   2967  <p><strong>The perfect candidate:</strong></p>...  Mobile Developer (React Native)  gradle, javascript, jenkins, jest, react nativ...       0.673913             7              4               [javascript, jenkins, xcode, gradle]                 []                  0.8            0.957447                  0.003469            0.51   715.677812  0.477792
