# %%
# Import libraries
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame
from efficient_apriori import apriori
import numpy as np
from dfply import *

from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from fuzzywuzzy import fuzz

# %%
# Functions to be used
def load_data(file):
    return pd.read_csv(file)

# %%
# Data loading
HiredCandidates_df = load_data("HiredCandidates.csv")
HiredJobs_df = load_data("HiredJobDetails.csv")

Candidates_df = load_data("AvailableCandidates.csv")
JobsToPredict_df = load_data("JobsToPredict.csv")

# %% [markdown]
# ### Feature Engineering

# %%
# Splitting Skills into separate elements in a list
HiredJobs_df['Skills'] = HiredJobs_df['Skills'].apply(lambda v: v.rsplit(', '))
HiredCandidates_df['Skills'] = HiredCandidates_df['Skills'].apply(lambda v: v.rsplit(', '))

Hired_df = pd.merge(HiredJobs_df, HiredCandidates_df, left_on='JobId', right_on='HiredForJobId')

# %% [markdown]
# ### EDA

# %%
# Candidates to be hired by position
CandidatesByPosition_df = Candidates_df.groupby(['UsersPosition']).size().to_frame('Candidate_count').reset_index()
CandidatesByPosition_df = CandidatesByPosition_df.sort_values('Candidate_count', ascending = False).head(10)

# %%
# Hired Candidates by position
HiredCandidatesByPosition_df = HiredCandidates_df.groupby(['UsersPosition']).size().to_frame('Candidate_count').reset_index()
HiredCandidatesByPosition_df = HiredCandidatesByPosition_df.sort_values('Candidate_count', ascending = False).head(10)

# %%
# Hired Jobs
HiredJobsPosition_df = HiredJobs_df.groupby(['POSITION']).size().to_frame('Jobs_count').reset_index()
HiredJobsPosition_df = HiredJobsPosition_df.sort_values('Jobs_count', ascending = False).head(10)

# %%
CandidatesByPosition_df.sort_values('Candidate_count', ascending = False).head(10)
# Out:
#                   UsersPosition  Candidate_count
# 4684          Software Engineer              462
# 4566         Software Developer              393
# 1847       Full Stack Developer              265
# 4324   Senior Software Engineer              144
# 5596              Web Developer              106
# 2772             Java Developer              101
# 1241                  Developer               87
# 4302  Senior Software Developer               72
# 389           Android Developer               64
# 1948   Full Stack Web Developer               55

# %%
# Have to add labels/color
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot Talent pool by positions
sns.set_color_codes("pastel")
sns.barplot(x="Candidate_count", y="UsersPosition", data=CandidatesByPosition_df,
            label="Total", color="b")

# %%
# Plot hired candidates by positions
sns.set_color_codes("pastel")
sns.barplot(x="Candidate_count", y="UsersPosition", data=HiredCandidatesByPosition_df,
            label="Total", color="b")

# %%
# Plot jobs hired by positions
sns.set_color_codes("pastel")
sns.barplot(x="Jobs_count", y="POSITION", data=HiredJobsPosition_df,
            label="Total", color="b")

# %%
# Apriori algorithm to find associations between skills
# itemsets, rules = apriori(skills, min_support=0.5,  min_confidence=1)
# print(rules)

# %%
# SKills_x = Job posting skills
# Skills_y = Candidate skills

# %%
#Hired_df = pd.merge(HiredJobs_df, HiredCandidates_df, left_on='JobId', right_on='HiredForJobId')

# %%
# Hired_df['Skills_x'] = Hired_df['Skills_x'].apply(lambda v: v.rsplit(', '))
# Hired_df['Skills_y'] = Hired_df['Skills_y'].apply(lambda v: v.rsplit(', '))

# %%
def FindSkillsMatched(df_name,skills_left, skills_right):
    for i in range(len(df_name)):
        SkillsMatched.append(list(set(Hired_df[skills_left][i]) & set(Hired_df[skills_right][i])))
        
        while i == len(df_name):
            df_name['SkillsMatched'] = SkillsMatched

# %%
FindSkillsMatched(Hired_df, 'Skills_x', 'Skills_y')

# %%
# Finding skills that match both on Job desc and candidate profile
def FindMatched():
    for i in range(len(Hired_df)):
        SkillsMatched.append(list(set(Hired_df['Skills_x'][i]) & set(Hired_df['Skills_y'][i])))

SkillsMatched = []
FindMatched()
Hired_df['SkillsMatched'] = SkillsMatched

# Finding match percentage
def FindMatchPercent():
    for i in range(len(Hired_df)):
        MatchPercent.append(round(len(Hired_df['SkillsMatched'][i])/len(Hired_df['Skills_x'][i])* 100, 2))
        
MatchPercent = []
FindMatchPercent()
Hired_df['MatchPercent'] = MatchPercent

# Adding #skills for each hired candidate
def FindSkillsNum():
    for i in range(len(Hired_df)):
        SkillsNum.append(len(Hired_df['Skills_y'][i]))
        
SkillsNum = []
FindSkillsNum()
Hired_df['SkillsNum'] = SkillsNum

# Adding Position match between Job posting and hired candidate
PositionMatch = []
def CalculatePositionMatch():
    for i in range(len(Hired_df)):
        PositionMatch.append(fuzz.token_sort_ratio(Hired_df['POSITION'][i], Hired_df['UsersPosition'][i]))
        
CalculatePositionMatch()
Hired_df['PositionMatch'] = PositionMatch

# %%
# Candidates with Top# of Skills
(Hired_df.sort_values(by='SkillsNum', ascending=False).head(10) >>
select(X.JobId, X.POSITION, X.UsersPosition, X.SkillsMatched, X.MatchPercent, X.SkillsNum))
# Out:
#      JobId                               POSITION  \
# 165   1630                     Software Developer
# 133   1289                  Senior Java Developer
# 144   1590              Senior Software Developer
# 29    1762                      C# .NET Developer
# 121   1264             Senior Front End Developer
# 126   1446            Senior Full Stack Developer
# 181   1797                   SR Developer in Test
# 66    1177  Fullstack Javascript/NodeJS Developer
# 166   1662                     Software Developer
# 10     976                  senior Java Developer
#
#                                     UsersPosition  \
# 165  An IT professional with 19+ years experience
# 133                      Senior Software Engineer
# 144                          Full Stack Developer
# 29               Experienced Full Stack Developer
# 121        Make a better world through technology
# 126                      Senior Software Engineer
# 181               Software QA Automation Engineer
# 66                      Senior Software Developer
# 166                          Full-Stack Developer
# 10       Java Architect and Senior Java Developer
#
#                                          SkillsMatched  MatchPercent  \
# 165                                 [python, react.js]        100.00
# 133  [java, angular, full stack, html, javascript, ...         87.50
# 144   [mysql, angular, python, javascript, typescript]         62.50
# 29               [c#, sql, typescript, css, bootstrap]         83.33
# 121  [agile methodologies, angular, rest api, git, ...         61.54
# 126       [mysql, php, rest api, javascript, react.js]         55.56
# 181  [qa, java, unit testing, test automation, sele...        100.00
# 66      [html, node.js, javascript, aws, css, mochajs]         75.00
# 166                              [node.js, javascript]        100.00
# 10   [java, design patterns, rest api, mongodb, agi...         76.92
#
#      SkillsNum
# 165        220
# 133        127
# 144         71
# 29          66
# 121         65
# 126         65
# 181         64
# 66          63
# 166         58
# 10          58

# %%
Hired_df['SkillsNum'].describe()
# Out:
# count    202.000000
# mean      27.099010
# std       21.666401
# min        1.000000
# 25%       14.000000
# 50%       22.000000
# 75%       37.750000
# max      220.000000
# Name: SkillsNum, dtype: float64

# %%
# Instresting find/ 13 Candidates with no skill match got hired
Hired_df[Hired_df['MatchPercent']== 0.00].head()
# Out:
#     JobId                                   Responsibilities  \
# 14   1318  <p>Design and develop a robust Akamai solution...
# 20   1444  <p>Toronto based company looks for a Back End ...
# 21   1444  <p>Toronto based company looks for a Back End ...
# 22   1561  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...
# 33   1584  <ul>\n  <li>An undergraduate degree in Compute...
#
#                        POSITION  \
# 14             Akamai Developer
# 20  Back End Software Developer
# 21  Back End Software Developer
# 22            Backend Developer
# 33                Data Engineer
#
#                                              Skills_x  UserId  HiredForJobId  \
# 14   [akamai, angular, apache, aws, azure, cassandra]  697973           1318
# 20  [any programmer language, mysql, nosql, orient...  678956           1444
# 21  [any programmer language, mysql, nosql, orient...  768863           1444
# 22                              [backend development]  681622           1561
# 33           [blockchain technologies, hadoop, spark]  639994           1584
#
#                                              Skills_y  \
# 14  [problem solving, engagement, troubleshooting,...
# 20  [javascript, angular, mongodb, aws, git, react...
# 21  [docker, java, spring boot, mongodb, python, m...
# 22  [microservices, java, rest api, soap, web serv...
# 33  [machine learning, relational database, sql, i...
#
#                                   UsersPosition SkillsMatched  MatchPercent  \
# 14  Skilled Engineer looking for new challenges            []           0.0
# 20                            Software Engineer            []           0.0
# 21                            Software Engineer            []           0.0
# 22                     Senior Software Engineer            []           0.0
# 33                                 Data Analyst            []           0.0
#
#     SkillsNum  PositionMatch
# 14          8             24
# 20          7             59
# 21          6             59
# 22         39             29
# 33         23             32

# %% [markdown]
# ### Data Modelling

# %%
# fit model no training data
model = XGBClassifier()
#model.fit(Hired_df, Candidates_df)

# %%
X =Hired_df.groupby(['MatchPercent']).size().to_frame('MatchPercent_count').reset_index()

# %%
# Range of Skill match percent that got hired
sns.scatterplot(x='MatchPercent', y="MatchPercent_count", size ='MatchPercent_count', data=X)

# %%
#Refining Candidate Profiles
FilteredCandidates_df = Candidates_df[Candidates_df['EnglishLevel']!=0] # Removing Candidates with English level '0'
FilteredCandidates_df = FilteredCandidates_df[(FilteredCandidates_df['YearsOfExperience']!=0) & #and no xp with Eng '1'
                                              (FilteredCandidates_df['EnglishLevel']!=1)].reset_index()

Candidates_df['Skills'] = Candidates_df['Skills'].apply(lambda v: v.rsplit(', '))
FilteredCandidates_df['Skills'] = FilteredCandidates_df['Skills'].apply(lambda v: v.rsplit(', '))

# %% [markdown]
# #### Test on 1 data point from candidates

# %%
#FilteredCandidates_df = FilteredCandidates_df.reset_index()

# %%
FilteredCandidates_df.head(1)
# Out:
#    index  UserId                                             Skills  \
# 0      1  533339  [ruby on rails, sql server, javascript, html5,...
#
#               UsersPosition  YearsOfExperience  EnglishLevel
# 0  Web Developer Fullstack                   9             4

# %%
def FindSkillsMatched(df_name,skills_left, skills_right):
    for i in range(len(df_name)):
        SkillsMatched.append(list(set(Hired_df[skills_left][i]) & set(Hired_df[skills_right][i])))
        
        while i == len(df_name):
            df_name['SkillsMatched'] = SkillsMatched

# %%
Positions_to_hire = list(JobsToPredict_df.POSITION)

# %%
Positions_to_hire
# Out:
# ['Backend Developer',
#  'Backend NodeJS Developer',
#  'Cloud DevOps Specialist',
#  'Game Developer',
#  'Mobile Developer (React Native)',
#  'Senior Front End Engineer',
#  'Senior Mobile App Developer',
#  'Software Developer',
#  'Sr Backend Developer (Python)',
#  'Sr Backend Engineer (Java)']

# %%
# For each candidate find the best suited position being offered
def bestfit_position():
# Out:
#   File "<ipython-input-836-92570d9cfd1e>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def CalculatePositionMatch():
    for i,k in range(len(JobsToPredict_df),range(len(FilteredCandidates_df)):
        PositionMatch.append(fuzz.token_sort_ratio(JobsToPredict_df['POSITION'][i], FilteredCandidates_df['UsersPosition'][i]))

# %%
for i in range(len(FilteredCandidates_df)):
    list(set(FilteredCandidates_df['Skills'][i]) & set(JobsToPredict_df['Skills'][i]))

# %% [markdown]
# ### Create False Dataset with 200 random candidates who are unlikely to get hired

# %% [markdown]
# ##### Conditions for getting Candidate unlikely to be hired:
#   * Candidate skills match with already hired jobs must be low ( selected >.20 <.30 for sample)
#   * Position match should be low
#   * Experience must be low with low Engish level

# %%
# Df names
HiredCandidates_df
HiredJobs_df
Hired_df

Candidates_df
JobsToPredict_df
# Out:
#    JobId                                   Responsibilities  \
# 0   3030  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...
# 1   3018  <p>A global event travel tech company with off...
# 2   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...
# 3   2946  <p>&nbsp;<em>Good communication skills</em><br...
# 4   2967  <p><strong>The perfect candidate:</strong></p>...
# 5   3020  <p>Awesome company in Toronto is hiring for se...
# 6   3009  <p><strong>Must-have-skills</strong></p>\n<p>-...
# 7   3022  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...
# 8   3015  <p>Waterloo based startup is hiring a Sr Back ...
# 9   2957  <p>Great startup located in the vibrant Berlin...
#
#                           POSITION  \
# 0                Backend Developer
# 1         Backend NodeJS Developer
# 2          Cloud DevOps Specialist
# 3                   Game Developer
# 4  Mobile Developer (React Native)
# 5        Senior Front End Engineer
# 6      Senior Mobile App Developer
# 7               Software Developer
# 8    Sr Backend Developer (Python)
# 9       Sr Backend Engineer (Java)
#
#                                               Skills
# 0  api, aws, google cloud, java, mongodb, node.js...
# 1  angular, http, javascript, node.js, react.js, ...
# 2                    aws, jboss, linux, perl, python
# 3                    c, c++, game development, unity
# 4  gradle, javascript, jenkins, jest, react nativ...
# 5           angular, css, html, javascript, react.js
# 6  dart, ionic framework, javascript, kotlin, nat...
# 7                      angular, javascript, react.js
# 8  aws, continuos deployment, continuous integrat...
# 9  clean code, ddd, distributed systems developme...

# %%
HiredCandidates_df
# Out:
#      UserId  HiredForJobId                                             Skills  \
# 0    533441           1357  [django, docker, typescript, flask, numpy, pan...
# 1    634908           1265  [oop, nosql, agile, agile development methodol...
# 2    635261           1590  [fast learning, strong communication skills, g...
# 3    635309           1635  [css, html, xml, mobile development, e-commerc...
# 4    635575           1797  [unity, android studio, xcode, gradle, ant, ma...
# ..      ...            ...                                                ...
# 197  868605           1416  [python, ruby on rails, vue.js, react.js, reac...
# 198  899238           2867  [resque, mvc, postgresql, flux, backbone.js, b...
# 199  899598           1677  [j2ee, celery, kafka, rabbit mq, django, sql, ...
# 200  911871           2896  [full stack, sql, angular, javascript, react.j...
# 201  955025           1770  [project coordination, project management, bus...
#
#                                         UsersPosition
# 0                              Senior Developer / CTO
# 1                                Full Stack Developer
# 2                                    Mobile Developer
# 3                                       Web Developer
# 4                     Software QA Automation Engineer
# ..                                                ...
# 197                              Full Stack Developer
# 198                Full Stack Ruby on Rails Developer
# 199  Java/python/javascript webapp/REST API developer
# 200                       Senior Full Stack Developer
# 201                           Computer Engineer | MBA
#
# [202 rows x 4 columns]

# %%
for i,j in range(len(Candidates_df)), range(len(HiredCandidates_df)):
    while j < len(HiredCandidates_df):
        set(Candidates_df['Skills'][i]) & set(HiredCandidates_df['Skills'][i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-862-66cc821a5a86> in <module>
# ----> 1 for i,j in range(len(Candidates_df)), range(len(HiredCandidates_df)):
#       2     while j < len(HiredCandidates_df):
#       3         set(Candidates_df['Skills'][i]) & set(HiredCandidates_df['Skills'][i])
#
# ValueError: too many values to unpack (expected 2)

# %%
Available = Candidates_df.sample(n = 100, random_state=7)
Hired = HiredCandidates_df.sample(n = 20, random_state=7)

# %%
HiredCandidates_df.head()
# Out:
#    UserId  HiredForJobId                                             Skills  \
# 0  533441           1357  [django, docker, typescript, flask, numpy, pan...
# 1  634908           1265  [oop, nosql, agile, agile development methodol...
# 2  635261           1590  [fast learning, strong communication skills, g...
# 3  635309           1635  [css, html, xml, mobile development, e-commerc...
# 4  635575           1797  [unity, android studio, xcode, gradle, ant, ma...
#
#                      UsersPosition
# 0           Senior Developer / CTO
# 1             Full Stack Developer
# 2                 Mobile Developer
# 3                    Web Developer
# 4  Software QA Automation Engineer

# %%
# For all available candidates calculating skill match with all hired jobs
d=[]
for i in range(len(Available)):
    for j in range(len(Hired)):
        a = round(len(list(set(Candidates_df['Skills'][i]) & set(HiredCandidates_df['Skills'][j])))/len(HiredCandidates_df['Skills'][j]),2)
        p = Candidates_df['UserId'][i]
        can_pos = Candidates_df['UsersPosition'][i]
        
        q = HiredCandidates_df['UserId'][j]
        hired_pos = HiredCandidates_df['UsersPosition'][j]
        d.append({'Candidate_id': p, 'CandidatePosition': can_pos, 'SkillMatch': a, 'Hired_User_id': q, 'HiredPosition': hired_pos })
d = pd.DataFrame(d)
d.head()
# Out:
#    Candidate_id  CandidatePosition  SkillMatch  Hired_User_id  \
# 0        533334  Software Engineer         0.0         533441
# 1        533334  Software Engineer         0.0         634908
# 2        533334  Software Engineer         0.0         635261
# 3        533334  Software Engineer         0.0         635309
# 4        533334  Software Engineer         0.0         635575
#
#                      HiredPosition
# 0           Senior Developer / CTO
# 1             Full Stack Developer
# 2                 Mobile Developer
# 3                    Web Developer
# 4  Software QA Automation Engineer

# %%
# Limiting candidates who have skill match between .10 & .13 returning just 550 out of 2000 datapoints
d = d[(d['SkillMatch'] > 0.20) & (d['SkillMatch'] < 0.30)]

# %%
d['SkillMatch'].describe()
# Out:
# count    116.000000
# mean       0.115603
# std        0.004985
# min        0.110000
# 25%        0.110000
# 50%        0.120000
# 75%        0.120000
# max        0.120000
# Name: SkillMatch, dtype: float64

# %%
d.sort_values(by = 'SkillMatch', ascending= False)
# Out:
#       Candidate_id                                  CandidatePosition  \
# 21          533339                           Web Developer Fullstack
# 1457        553625  Software Engineer · Web Expert · Automated Tes...
# 1421        553623                                  Software Engineer
# 1397        553621                                      Data Engineer
# 1261        553577                                     Java Developer
# ...            ...                                                ...
# 353         533412    Support Analyst, Front-End Developer and DevOps
# 1471        553626                                  Software Engineer
# 1494        553630                                 Software Developer
# 1506        553632                               PHP Senior Developer
# 1994        603610                                  Android Developer
#
#       SkillMatch  Hired_User_id             HiredPosition
# 21          0.12         634908      Full Stack Developer
# 1457        0.12         638625  Senior Software Engineer
# 1421        0.12         634908      Full Stack Developer
# 1397        0.12         638625  Senior Software Engineer
# 1261        0.12         634908      Full Stack Developer
# ...          ...            ...                       ...
# 353         0.11         637998  Test Automation Engineer
# 1471        0.11         637760      Full Stack Developer
# 1494        0.11         638045            Java Developer
# 1506        0.11         635780         Software Engineer
# 1994        0.11         638045            Java Developer
#
# [116 rows x 5 columns]

# %%
# Selecting just one random data point for each candidate from dataset d
rand_candidates = []
for i in d['Candidate_id'].unique():
    rand_candidates.append(d[d['Candidate_id'] == i].sample(n = 1, random_state=7))

# %%
len(d['Candidate_id'].unique())
# Out:
# 34

# %%
rand_candidates = pd.concat(rand_candidates, ignore_index=True)

# %%
#rand_candidates.reset_index(inplace=True, drop=True)

# %%
rand_candidates = rand_candidates.sort_index(axis=1)

# %%
idx = Candidates_df.index.intersection(rand_candidates.index)
print (idx)
# Out:
# RangeIndex(start=0, stop=34, step=1)

# %%
# Candidates who are likely not to be hired
FalseCandidates_df = Candidates_df.ix[idx]

# Removing candidates without experience and with English level = 0
FalseCandidates_df = FalseCandidates_df[(FalseCandidates_df['YearsOfExperience']!=0) & (FalseCandidates_df['EnglishLevel']!=0)]
# Out:
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
FalseCandidates_df['Target'] = 0
HiredCandidates_df['Target'] = 1

Hired_final_df = pd.concat([HiredCandidates_df, FalseCandidates_df])
# Out:
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %% [markdown]
# #### Prediction using Logistic model

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
Candidates_test_df = Candidates_df.sample(n = 150, random_state=7)
Candidates_test_df['Target'] = 0

# %%
cols = X_clean_df.columns.tolist()
cols = ['UserId', 'UsersPosition', 'Skills', 'Target']

X_train_df = Hired_final_df.drop(columns = ['EnglishLevel','HiredForJobId', 'YearsOfExperience']).copy()
X_train_df = X_train_df[cols]

Y_train_df = Candidates_test_df.drop(columns = ['EnglishLevel', 'YearsOfExperience']).copy()
Y_train_df = Y_train_df[cols]

X_train_df['train'] = 1
Y_train_df['train'] = 1


train_df = pd.concat([X_train_df, Y_train_df])

# %%
X_test = Candidates_df.sample(n = 50, random_state=7)

# %%
X_test
# Out:
#       UserId  UsersPosition   php,joomla,magneto,bootstrap  .net  \
# 1977  644007             23                              0     0
# 3880  655476             42                              0     0
# 52    533529             17                              0     0
# 3044               0          0    0        0      0    0               0
# 3498               0          0    1        0      0    0               0
# 5524               0          0    0        0      0    0               0
# 9554               0          0    0        0      0    0               0
# 2846               0          0    0        0      0    0               0
# 835                0          0    0        0      0    0               0
# 4863               0          0    0        0      0    0               0
# 3297               0          1    0        0      0    0               0
# 7961               0          1    0        0      0    0               0
# 3145               0          0    0        0      0    0               0
# 6115               0          1    0        0      0    0               0
# 1901               0          0    0        0      0    0               0
# 1411               0          0    0        0      0    0               0
# 623                0          0    0        1      0    0               0
# 3503               0          0    0        0      0    0               0
# 3066               0          0    0        0      0    0               0
# 641                0          0    0        0      0    0               1
#
# [50 rows x 776 columns]

# %%
combined_df = pd.concat([X_train_df, Y_train_df])

# %%
combined_df
# Out:
#       UserId                                   UsersPosition  \
# 0     533441                          Senior Developer / CTO
# 1     634908                            Full Stack Developer
# 2     635261                                Mobile Developer
# 3     635309                                   Web Developer
# 4     635575                 Software QA Automation Engineer
# ...      ...                                             ...
# 533   636450                             ABAP Sr. Programmer
# 2755  648041                              Software Developer
# 7167  671687  A Brazilian student of information technology.
# 1657  642388   Ad Manager, Programmatic, Analytics & Adwords
# 2971  649439                     Java C++ Software Developer
#
#                                                  Skills  Target  train
# 0     [django, docker, typescript, flask, numpy, pan...       1      1
# 1     [oop, nosql, agile, agile development methodol...       1      1
# 2     [fast learning, strong communication skills, g...       1      1
# 3     [css, html, xml, mobile development, e-commerc...       1      1
# 4     [unity, android studio, xcode, gradle, ant, ma...       1      1
# ...                                                 ...     ...    ...
# 533                                [debian, linux, sap]       0      0
# 2755  [sql, javascript, html5, css3, webdesign, my s...       0      0
# 7167                         [3d studio max html5, php]       0      0
# 1657  [english, crm, erp, social media, digital mark...       0      0
# 2971  [c++, postgresql, pl/sql, vb6, oracle db, shel...       0      0
#
# [370 rows x 5 columns]

# %%
# Converting skills to dummies

skills_df = pd.get_dummies(combined_df['Skills'].apply(pd.Series).stack()).sum(level=0)
combined_df = combined_df.loc[~combined_df.index.duplicated(keep='first')]
skills_df = skills_df.loc[~skills_df.index.duplicated(keep='first')]

combined_df = pd.concat([combined_df, skills_df], axis= 1)
combined_df = combined_df.drop(columns = ['Skills'])

# %%
# Encoding UserPosition using LabelEncoder()
le_UserPosition = LabelEncoder()

combined_df['UsersPosition'] = le_UserPosition.fit_transform(combined_df['UsersPosition'])

# %%
# Separating into Train_X and Train_Y datasets
X_df = combined_df[combined_df['train']==1].copy()
Y_df = combined_df[combined_df['train']==0].copy()

X_df.drop(["train"], axis=1, inplace=True)
Y_df.drop(["train"], axis=1, inplace=True)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')

# %%
enc.fit(Candidates_test_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     104         try:
# --> 105             res = _encode_python(values, uniques, encode)
#     106         except TypeError:
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\preprocessing\label.py in _encode_python(values, uniques, encode)
#      58     if uniques is None:
# ---> 59         uniques = sorted(set(values))
#      60         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1330-f24661823ccb> in <module>
# ----> 1 enc.fit(Candidates_test_df)
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     491             return self
#     492         else:
# --> 493             self._fit(X, handle_unknown=self.handle_unknown)
#     494             self.drop_idx_ = self._compute_drop_idx()
#     495             return self
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown)
#      90             Xi = X_list[i]
#      91             if self._categories == 'auto':
# ---> 92                 cats = _encode(Xi)
#      93             else:
#      94                 cats = np.array(self._categories[i], dtype=Xi.dtype)
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     105             res = _encode_python(values, uniques, encode)
#     106         except TypeError:
# --> 107             raise TypeError("argument must be a string or number")
#     108         return res
#     109     else:
#
# TypeError: argument must be a string or number

# %%
from sklearn.linear_model import LogisticRegression

# %%
logisticRegr = LogisticRegression()

# %%
X = combined_df
Y = combined_df.loc[:, combined_df.columns == 'Target']

# %%
X.shape
# Out:
# (348, 1334)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X_df, Y_df,random_state = 50 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1595-2ec0854dcf9b> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X_df, Y_df,random_state = 50 )
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [202, 146]

# %%
X_test
# Out:
#       UserId                                             Skills  \
# 1977  644007  [iso 27002, infrastructure, team leadership, i...
# 3880  655476  [javascript, node.js, github, react.js, proble...
# 52    533529  [tdd, ruby on rails, scrum, html5, postgresql,...
# 2551  646783  [pmi, iso 27001, itil, software development, f...
# 2246  645200  [scrum, c++, html5, css3, agile methodologies,...
# 270   634895  [scrum, pmi, ionic framework, pmbok, itil foun...
# 601   636880  [electronic, vray, music production, 3d studio...
# 2441  646191  [ux, ui, front end, product design, mobile des...
# 3286  651709  [javascript, laravel, zend framework, bootstra...
# 2967  649403  [scrum, python, apache, docker, vagrant, unix,...
# 4712  660617  [sql, javascript, wordpress, web development, ...
# 9032  678716  [javascript, uml, 3d studio max html5, oracle ...
# 1787  643114  [sql server, javascript, weblogic, jboss eap/w...
# 1698  642616  [javascript, english, html5, json, swift, ios,...
# 3225  651274  [sql server, javascript, mvc, bootstrap, web d...
# 403   635703  [node.js, ansible, freebsd, kubernetes, linux,...
# 3534  653473  [sql, sql server, scrum, javascript, pl/sql, v...
# 6046  667102  [python, laravel, c, html5, css3, mongodb, goo...
# 3047  649953     [c, c++, intellij, linux, mulesoft, java, git]
# 8862  678107  [sql, sql server, javascript, wcf, html5, delp...
# 7146  671605  [sql, scrum, laravel, zend framework, html5, b...
# 507   636306  [sql server, python, uml, wcf, node.js, scala,...
# 4476  658964  [ruby on rails, scrum, javascript, spring, uml...
# 1677  642468  [branding, design patterns, ux, responsive web...
# 2020  644218  [sql server, javascript, laravel, english, htm...
# 1682  642482  [tdd, ddd, wcf, web api, web forms, react.js, ...
# 1649  642335  [android, scrum, swift, ios, objective-c, agil...
# 2421  646101  [android, tdd, sql, scrum, javascript, nhibern...
# 7537  673112  [xml, unix, 3d studio max html5, subversion (t...
# 4793  661147  [windows server, dns, dhcp, computer network, ...
# 9636  680692  [javascript, node.js, react.js, php, react nat...
# 1015  639069  [javascript, html5, postgresql, css3, node.js,...
# 8921  678272  [sql, javascript, weblogic, uml, json, postgre...
# 3044  649927  [spring, agile development methodology, mongod...
# 3498  653274  [sql, javascript, html5, wpf, node.js, react.j...
# 5524  665037  [sql server, scrum, javascript, mvc, wcf, html...
# 9554  680432  [communication, managing budgets, training & m...
# 2846  648605  [fireworks, adobe illustrator, ux, sketch, key...
# 835   638109  [javascript, postgresql, jsf, hibernate, node....
# 4863  661664     [react.js, quality assurance, test automation]
# 3297  651819  [wordpress, laravel, html5, bootstrap, seo, gu...
# 7961  674818  [sql, wordpress, c, c++, html5, css3, arduino,...
# 3145  650637  [digital marketing, marketing communications, ...
# 6115  667378  [sql, laravel, web development, devops, wordpr...
# 1901  643608  [english, business administration, portuguese,...
# 1411  641088  [android, html5, postgresql, jsf, hibernate, e...
# 623   636981  [tdd, sql server, scrum, css3, pl/sql, phonega...
# 3503  653306  [soap, test planning and test script, jira, ag...
# 3066  650030  [software developer, software architecture, so...
# 641   637104  [sql, sql server, scrum, javascript, pmi, zend...
#
#                                           UsersPosition
# 1977   IT Governance / Service Delivery / IT Leadership
# 3880                                      Web Developer
# 52                    Fullstack Ruby on Rails Developer
# 2551  Global Information Security Manager and Strate...
# 2246                            Server System Operation
# 270                   Enterprise and Solution Architect
# 601                                           Goldsmith
# 2441             Product Designer & Front-End Developer
# 3286            Full Stack Web Developer & DevOps (AWS)
# 2967                 Site Reliability Engineer / DevOps
# 4712                            Fullstack web developer
# 9032                                Analyst / Developer
# 1787                                     Java Developer
# 1698                               iOS Mobile Developer
# 3225             SQL/.Net Developer/Technical Team Lead
# 403                         IT specialist and developer
# 3534                   SAP Hana | UI5 | Abap Consultant
# 6046                           Web and Mobile Developer
# 3047                                  Computer Engineer
# 8862                                 Software Developer
# 7146                             PHP Developer Analyst
# 507       Bigdata Solution Architect | System Architect
# 4476                          Senior Software Developer
# 1677            Digital, Graphic and Interface Designer
# 2020                    FullStack Dev, PHP, React, Node
# 1682                         Experienced .NET Developer
# 1649                                     iOS Specialist
# 2421                          Full Stack Developer .Net
# 7537                                  Senior Consultant
# 4793         Computer network administrator/technician
# 9636                    Full Stack JavaScript developer
# 1015                               Full stack developer
# 8921                                    Systems Analyst
# 3044                                 Software Developer
# 3498                       Fullstack software developer
# 5524                    Senior .NET FullStack Developer
# 9554            Head Planning, Development and Strategy
# 2846                     UI/UX Designer, Brand Designer
# 835                            Java Fullstack Developer
# 4863                                       Web Engineer
# 3297                               FRONT-END DEVELOPER
# 7961           Engineer of Control and Automation, Msc.
# 3145                     Commercial & Marketing Manager
# 6115                               Enterprise Architect
# 1901                                    Project Manager
# 1411                                Degree in Computing
# 623                                   Software Engineer
# 3503                          Senior Quality Assurance
# 3066                               Enterprise Architect
# 641                           Web Developer Team Leader

# %%
X_test.drop(columns = ['EnglishLevel', 'YearsOfExperience'], axis=1, inplace=True)

# %%
skills_df = pd.get_dummies(X_test['Skills'].apply(pd.Series).stack()).sum(level=0)
X_test = X_test.loc[~X_test.index.duplicated(keep='first')]
skills_df = skills_df.loc[~skills_df.index.duplicated(keep='first')]

X_test = pd.concat([X_test, skills_df], axis= 1)
X_test = X_test.drop(columns = ['Skills'])

# %%
X_test['UsersPosition'] = le_UserPosition.fit_transform(X_test['UsersPosition'])

# %%
logisticRegr.fit(X, Y)
# Out:
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_test
# Out:
#       UserId                                      UsersPosition  \
# 1977  644007   IT Governance / Service Delivery / IT Leadership
# 3880  655476                                      Web Developer
# 52    533529                  Fullstack Ruby on Rails Developer
# 2551  646783  Global Information Security Manager and Strate...
# 2246  645200                            Server System Operation
# 270   634895                  Enterprise and Solution Architect
# 601   636880                                          Goldsmith
# 2441  646191             Product Designer & Front-End Developer
# 3286  651709            Full Stack Web Developer & DevOps (AWS)
# 2967  649403                 Site Reliability Engineer / DevOps
# 4712  660617                            Fullstack web developer
# 9032  678716                                Analyst / Developer
# 1787  643114                                     Java Developer
# 1698  642616                               iOS Mobile Developer
# 3225  651274             SQL/.Net Developer/Technical Team Lead
# 403   635703                        IT specialist and developer
# 3534  653473                   SAP Hana | UI5 | Abap Consultant
# 6046  667102                           Web and Mobile Developer
# 3047  649953                                  Computer Engineer
# 8862  678107                                 Software Developer
# 7146  671605                             PHP Developer Analyst
# 507   636306      Bigdata Solution Architect | System Architect
# 4476  658964                          Senior Software Developer
# 1677  642468            Digital, Graphic and Interface Designer
# 2020  644218                    FullStack Dev, PHP, React, Node
# 1682  642482                         Experienced .NET Developer
# 1649  642335                                     iOS Specialist
# 2421  646101                          Full Stack Developer .Net
# 7537  673112                                  Senior Consultant
# 4793  661147         Computer network administrator/technician
# 9636  680692                    Full Stack JavaScript developer
# 1015  639069                               Full stack developer
# 8921  678272                                    Systems Analyst
# 3044  649927                                 Software Developer
# 3498  653274                       Fullstack software developer
# 5524  665037                    Senior .NET FullStack Developer
# 9554  680432            Head Planning, Development and Strategy
# 2846  648605                     UI/UX Designer, Brand Designer
# 835   638109                           Java Fullstack Developer
# 4863  661664                                       Web Engineer
# 3297  651819                               FRONT-END DEVELOPER
# 7961  674818           Engineer of Control and Automation, Msc.
# 3145  650637                     Commercial & Marketing Manager
# 6115  667378                               Enterprise Architect
# 1901  643608                                    Project Manager
# 1411  641088                                Degree in Computing
# 623   636981                                  Software Engineer
# 3503  653306                          Senior Quality Assurance
# 3066  650030                               Enterprise Architect
# 641   637104                          Web Developer Team Leader
#
#        php,joomla,magneto,bootstrap  .net  3d studio max  3d studio max html5  \
# 1977                              0     0              0                    0
# 3880                              0     0              0                    0
# 52                                0     0              0                    0
# 2551                              0     0              0                    0
# 2246                              0     0              0                    0
# 270                               0     1              0                    0
# 601                               0     0              1                    0
# 2441                              0     0              0                    0
# 3286                              0     0              0                    0
# 2967                              0     0              0                    0
# 4712                              0     0              0                    0
# 9032                              0     0              0                    1
# 1787                              0     0              0                    0
# 1698                              0     0              0                    0
# 3225                              0     1              0                    0
# 403                               0     0              0                    0
# 3534                              0     1              0                    0
# 6046                              0     0              0                    0
# 3047                              0     0              0                    0
# 8862                              0     1              0                    0
# 7146                              0     0              0                    0
# 507                               0     1              0                    0
# 4476                              0     1              0                    0
# 1677                              0     0              0                    0
# 2020                              0     0              0                    0
# 1682                              0     1              0                    0
# 1649                              0     0              0                    0
# 2421                              0     1              0                    0
# 7537                              0     0              0                    1
# 4793                              0     0              0                    0
# 9636                              0     0              0                    0
# 1015                              0     1              0                    0
# 8921                              0     0              0                    0
# 3044                              0     0              0                    0
# 3498                              0     0              0                    0
# 5524                              0     1              0                    0
# 9554                              0     0              0                    0
# 1682            0           0        0               0          0    0
# 1649            0           0        0               0          0    0
# 2421            0           0        0               0          0    0
# 7537            0           0        0               0          0    0
# 4793            0           0        0               1          0    0
# 9636            0           0        0               0          0    0
# 1015            0           0        0               0          0    0
# 8921            0           0        0               0          0    0
# 3044            0           0        0               0          0    0
# 3498            0           0        0               0          0    1
# 5524            0           0        0               0          0    0
# 9554            0           0        0               0          0    0
# 2846            0           0        0               0          0    0
# 835             0           0        0               0          0    0
# 4863            0           0        0               0          0    0
# 3297            0           0        0               0          1    0
# 7961            0           0        0               0          1    0
# 3145            0           0        0               0          0    0
# 6115            0           0        0               0          1    0
# 1901            0           0        0               0          0    0
# 1411            0           1        0               0          0    0
# 623             0           0        0               0          0    0
# 3503            0           0        0               0          0    0
# 3066            0           0        0               0          0    0
# 641             0           0        0               0          0    0
#
#       xamarin  xcode  xml  zend framework
# 1977        0      0    0               0
# 3880        0      0    0               0
# 52          0      0    0               0
# 2551        0      0    0               0
# 2246        0      0    0               0
# 270         0      0    0               0
# 601         0      0    0               0
# 2441        0      0    0               0
# 3286        0      0    0               1
# 2967        0      0    0               0
# 4712        0      0    0               0
# 9032        0      0    0               0
# 1787        0      0    0               0
# 1698        0      1    0               0
# 3225        0      0    0               0
# 403         0      0    0               0
# 3534        0      0    0               0
# 6046        0      0    0               0
# 3047        0      0    0               0
# 8862        0      0    0               0
# 7146        0      0    0               1
# 507         0      0    0               0
# 4476        0      0    0               0
# 1677        0      0    0               0
# 2020        0      0    0               0
# 1682        0      0    0               0
# 1649        0      1    0               0
# 2421        0      0    0               0
# 7537        0      0    1               0
# 4793        0      0    0               0
# 9636        0      0    0               0
# 1015        0      0    0               0
# 8921        0      0    0               0
# 3044        0      0    0               0
# 3498        0      0    0               0
# 5524        0      0    0               0
# 9554        0      0    0               0
# 2846        0      0    0               0
# 835         0      0    0               0
# 4863        0      0    0               0
# 3297        0      0    0               0
# 7961        0      0    0               0
# 3145        0      0    0               0
# 6115        0      0    0               0
# 1901        0      0    0               0
# 1411        0      0    0               0
# 623         1      0    0               0
# 3503        0      0    0               0
# 3066        0      0    0               0
# 641         0      0    0               1
#
# [50 rows x 776 columns]

# %%
logisticRegr.predict(X_test[0:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1656-df5b79df3034> in <module>
# ----> 1 logisticRegr.predict(X_test[0:10])
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# F:\Learning\Anaconda3\envs\py37\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     268         if X.shape[1] != n_features:
#     269             raise ValueError("X has %d features per sample; expecting %d"
# --> 270                              % (X.shape[1], n_features))
#     271
#     272         scores = safe_sparse_dot(X, self.coef_.T,
#
# ValueError: X has 776 features per sample; expecting 1334

# %% [markdown]
# #### Transformations to make
# * Find corelation between jobs to hire skills and candidate skills to find the job with closest match.
# * Use FuzzyWuzzy to find match between position names
# * Convert Skills into list in each row - For apriori analysis
# * Convert Skills horizontally with 1s and 0s - For XGB boost or prediction modelling
#
#
# #### To do list
# * Feature Engineer Match % between Job skills and skills of candidates who got hired
# * Add colour to plots and change style for readablity and best practice
# * Add Emoji to plots
# * Change Column names to lowercase
#
# #### Plot Ideas
# * Job Demand/Talent supply graph( Two sided vertical bar plot)
#
# #### Pain points
# * Creating a new column by manipulating other columns using lambda function ( When column being manipulated is a list)
# * Have to think of a better way to match positions and to assign a value for each skill and maybe position name
