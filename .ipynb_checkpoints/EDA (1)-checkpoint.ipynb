# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from matplotlib import pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
import nltk
import seaborn as sns
import lightgbm as lgb
from nltk.corpus import stopwords
import matplotlib as mpl
nltk.download("stopwords") 
import re


pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
#pd.set_option('display.max_colwidth', -1)  # or 199
pd.set_option('display.expand_frame_repr', False)

df_users = pd.read_csv('HiredCandidates.csv').reset_index(drop=True)
df_users = df_users.rename(columns={'Skills':'UserSkills'})

df_jobs = pd.read_csv('HiredJobDetails.csv').reset_index(drop=True)
df_jobs = df_jobs.rename(columns={'POSITION':'JobsPosition','Skills':'JobSkills','Responsibilities':'JobResponsibilities'})

cols_to_use = df_jobs.columns.difference(df_users.columns)

df = pd.merge(df_users,df_jobs[cols_to_use],left_on=['HiredForJobId'],right_on=['JobId'],how='inner')
df['hired'] = 1

df.columns = df.columns.str.lower()
df.head()
# Out:
# d:\anaconda\envs\commonenv\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aswin.jesudhas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    userid  hiredforjobid                                         userskills             usersposition  jobid                                jobresponsibilities                                          jobskills                 jobsposition  hired
# 0  533441           1357  django, docker, typescript, flask, numpy, pand...    Senior Developer / CTO   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...                          javascript, ruby on rails   Lead BackEnd RoR Developer      1
# 1  696183           1357  ruby on rails, javascript, python, java, html,...         Software Engineer   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...                          javascript, ruby on rails   Lead BackEnd RoR Developer      1
# 2  696873           1357  c++, erlang, linux kernel, tcp/ip, web develop...  Senior Software Engineer   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...                          javascript, ruby on rails   Lead BackEnd RoR Developer      1
# 3  634908           1265  oop, nosql, agile, agile development methodolo...      Full Stack Developer   1265  <p><strong>The ideal candidate:</strong><br>\n...  agile, aws, continuous integration, java, java...  Senior Full Stack Developer      1
# 4  635261           1590  fast learning, strong communication skills, gi...          Mobile Developer   1590  <ul>\n  <li>4+ years experience in a related f...  angular, cloud computing, javascript, kubernet...    Senior Software Developer      1

# %%
# create features
print(df.columns.values)
# Out:
# ['userid' 'hiredforjobid' 'userskills' 'usersposition' 'jobid'
#  'jobresponsibilities' 'jobskills' 'jobsposition' 'hired']

# %%
def create_features(row):
    
    def cleanhtml(raw_html):
        cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
        cleantext = re.sub(cleanr, '', raw_html)
        return cleantext

    user_skills = str(row['userskills']).split(',')
    job_skills = str(row['jobskills']).split(',')
    #resp_skills = str(row['job_Responsibilities'])
    #resp_skills = cleanhtml(resp_skills).split(' ')

    #filtered_words = [word for word in resp_skills if word not in stopwords.words('english')]
    #best_match = process.extractOne(search_name, np.delete(all_values,idx) ,scorer=fuzz.token_sort_ratio)

    common_skills = []
    other_skills = []

    for skill in user_skills:
        if skill in job_skills:
            common_skills.append(skill)
        else:
            other_skills.append(skill)
            
    row['userskills_no'] = len(user_skills)
    row['jobskills_no'] = len(job_skills)
    row['common_skills'] = len(common_skills)

    row['common_skills_ratio'] = (len(common_skills)/len(job_skills)).__round__(2) # 1 is ideal
    row['other_skills_ratio'] = (len(other_skills)/len(user_skills)).__round__(2) # 0 is ideal
    row['job_candiate_skill_ratio'] = (len(job_skills)/len(user_skills)).__round__(2) # 1 is ideal

    #row['position_match'] = process.extractOne(str(row['user_UsersPosition']), str(row['job_POSITION']) ,scorer=fuzz.token_sort_ratio)[1]
    row['position_match'] = fuzz.token_sort_ratio(str(row['usersposition']), str(row['jobsposition']))
        
    return row

# %%
# Select neg cases - simple way
['userid' 'hiredforjobid' 'userskills' 'usersposition' 'jobid'
 'jobresponsibilities' 'jobskills' 'jobsposition']

df_available = pd.read_csv('AvailableCandidates.csv')
df_available['hired'] = 0
df_available = df_available.sample(n=df.shape[0],random_state=2).reset_index(drop=True)
df_available = df_available.rename(columns={'Skills':'UserSkills'})
df_available.columns = df_available.columns.str.lower()
df_available = df_available[['userid','userskills','usersposition','hired']]

df_jobs = df[['jobid','jobresponsibilities','jobsposition','jobskills']].reset_index(drop=True)

df_neg = pd.concat([df_available,df_jobs],axis=1)

df = df[df_neg.columns.values]
df = pd.concat([df,df_neg])

print(df.shape)
df.head()
# Out:
# (404, 8)
#    userid                                         userskills             usersposition  hired  jobid                                jobresponsibilities                 jobsposition                                          jobskills
# 0  533441  django, docker, typescript, flask, numpy, pand...    Senior Developer / CTO      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails
# 1  696183  ruby on rails, javascript, python, java, html,...         Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails
# 2  696873  c++, erlang, linux kernel, tcp/ip, web develop...  Senior Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails
# 3  634908  oop, nosql, agile, agile development methodolo...      Full Stack Developer      1   1265  <p><strong>The ideal candidate:</strong><br>\n...  Senior Full Stack Developer  agile, aws, continuous integration, java, java...
# 4  635261  fast learning, strong communication skills, gi...          Mobile Developer      1   1590  <ul>\n  <li>4+ years experience in a related f...    Senior Software Developer  angular, cloud computing, javascript, kubernet...

# %%
print(df.info())
df = df.apply(create_features,axis=1)
#df = df.sort_values(by='position_match',ascending=False)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 0 to 201
# Data columns (total 8 columns):
# userid                 404 non-null int64
# userskills             404 non-null object
# usersposition          404 non-null object
# hired                  404 non-null int64
# jobid                  404 non-null int64
# jobresponsibilities    402 non-null object
# jobsposition           404 non-null object
# jobskills              404 non-null object
# dtypes: int64(3), object(5)
# memory usage: 28.4+ KB
# None
#    userid                                         userskills             usersposition  hired  jobid                                jobresponsibilities                 jobsposition                                          jobskills  userskills_no  jobskills_no  common_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match
# 0  533441  django, docker, typescript, flask, numpy, pand...    Senior Developer / CTO      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails             23             2              0                 0.00                1.00                      0.09              65
# 1  696183  ruby on rails, javascript, python, java, html,...         Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails             15             2              0                 0.00                1.00                      0.13              37
# 2  696873  c++, erlang, linux kernel, tcp/ip, web develop...  Senior Software Engineer      1   1357  <p><br>\n</p>\n<p><strong>SEE THE FULL JOB DES...   Lead BackEnd RoR Developer                          javascript, ruby on rails             21             2              0                 0.00                1.00                      0.10              36
# 3  634908  oop, nosql, agile, agile development methodolo...      Full Stack Developer      1   1265  <p><strong>The ideal candidate:</strong><br>\n...  Senior Full Stack Developer  agile, aws, continuous integration, java, java...             40             9              7                 0.78                0.82                      0.23              85
# 4  635261  fast learning, strong communication skills, gi...          Mobile Developer      1   1590  <ul>\n  <li>4+ years experience in a related f...    Senior Software Developer  angular, cloud computing, javascript, kubernet...             15             8              1                 0.12                0.93                      0.53              59

# %%
plot_cols = df.columns.difference(['userid','userskills','usersposition','hired','jobid','jobresponsibilities','jobsposition','jobskills'])

for idx,col in enumerate(plot_cols):
    print(col)
    df_hired = df[df['hired'] == 1]
    df_hired[col].plot.hist()
    plt.show()
    
    df_nothired = df[df['hired'] == 0]
    df_nothired[col].plot.hist()
    plt.show()
# Out:
# common_skills
# common_skills_ratio
# job_candiate_skill_ratio
# jobskills_no
# other_skills_ratio
# position_match
# userskills_no

# %%
# simple binary classification

isDebug = False

print('Modeling columns',df.columns.values)

features = [ 'userskills_no','jobskills_no','common_skills','common_skills_ratio','other_skills_ratio',
            'job_candiate_skill_ratio','position_match','hired']

features = [ 'userskills_no','common_skills_ratio','other_skills_ratio',
            'job_candiate_skill_ratio','position_match','hired']

df_model = df.copy()
df_model = df_model[features]

y = pd.DataFrame(df_model['hired'])
X = df_model.loc[:, df_model.columns != 'hired']
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 if isDebug else 0.0049, random_state=42)

print('Training with {} and testing with {}'.format(X_train.shape[0],X_test.shape[0]))
train_dataset = lgb.Dataset(X_train, label=y_train)
test_dataset = lgb.Dataset(X_test, label=y_test)
    
np.random.seed(0)
nrounds = 10
params = {
    'objective': 'xentropy',
    'metric': "auc",
    'feature_fraction': 1,
    'bagging_fraction': 1,
    'early_stopping_rounds': 100,
    'verbose': -1
}
gbm = lgb.train(params, train_dataset,valid_sets=[test_dataset], num_boost_round=nrounds)


def plot_imp(model, X):
    feature_imp = pd.DataFrame(sorted(zip(model.feature_importance(),X.columns)),columns=['score','feature'])
    feature_imp = feature_imp.sort_values(by='score',ascending=False)

    # Plot the total crashes
    sns.set_color_codes("pastel")
    sns.barplot(x="score", y="feature",data=feature_imp.head(50),palette=mpl.cm.ScalarMappable(cmap='viridis_r').to_rgba((feature_imp["score"])))
    plt.xlabel("LGBM Importance score")
    plt.ylabel("Feature")
    plt.title("Feature Importance")

    # sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
    # plt.title('LightGBM Important Features')
    # plt.tight_layout()

plot_imp(gbm,X)
plt.show()
# Out:
# Modeling columns ['userid' 'userskills' 'usersposition' 'hired' 'jobid'
#  'jobresponsibilities' 'jobsposition' 'jobskills' 'userskills_no'
#  'jobskills_no' 'common_skills' 'common_skills_ratio' 'other_skills_ratio'
#  'job_candiate_skill_ratio' 'position_match']
# Training with 402 and testing with 2
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# Did not meet early stopping. Best iteration is:
# [1]	valid_0's auc: 1
# d:\anaconda\envs\commonenv\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
# Generate predictions
#y_pred = gbm.predict(X_test)

df_test =  pd.read_csv('JobsToPredict.csv')
df_test = df_test.rename(columns={'POSITION':'JobsPosition','Skills':'JobSkills','Responsibilities':'JobResponsibilities'})
df_test.columns = df_test.columns.str.lower()

#df_available = pd.read_csv(r'E:\Projects\PycharmProjects\Vanhack\data\AvailableCandidates.csv')
df_available = pd.read_csv('SmallCandidates.csv')
df_available = df_available.rename(columns={'Skills':'UserSkills'})
df_available.columns = df_available.columns.str.lower()
df_available = df_available[['userid','userskills','usersposition']]
df_available = df_available.reset_index(drop=True)

# Predict for each job with all candidates to get top 10 candidates

njobs = df_test.shape[0]
ncandidates = df_available.shape[0]

df_pred = df_test.iloc[[4]]
df_pred = df_pred.append([df_pred]*ncandidates,ignore_index=True)
df_pred = df_pred.reset_index(drop=True)

print(df_pred.shape)
df_pred.head()
# Out:
# (119, 4)
#    jobid                                jobresponsibilities             jobsposition                        jobskills
# 0   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python
# 1   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python
# 2   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python
# 3   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python
# 4   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python

# %%
print(df_available.columns.values,df_available.shape)
print(df_pred.columns.values,df_pred.shape)
df_pred = pd.concat([df_available,df_pred],axis=1)

df_pred = df_pred.apply(create_features,axis=1)
#df_pred = df_pred[features]

df_pred.head()
# Out:
# ['userid' 'userskills' 'usersposition'] (118, 3)
# ['jobid' 'jobresponsibilities' 'jobsposition' 'jobskills'] (119, 4)
#      userid                                         userskills                                      usersposition  jobid                                jobresponsibilities             jobsposition                        jobskills  userskills_no  jobskills_no  common_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match
# 0  553625.0   ruby on rails, javascript, docker, vue.js, linux  Software Engineer · Web Expert · Automated Tes...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              5             5              1                  0.2                 0.8                      1.00              35
# 1  614275.0  javascript, testing, node.js, jmeter, selenium...                           Specialized in QA & Test   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              0                  0.0                 1.0                      0.45              53
# 2  634713.0  c, testing, web development, css3, google anal...                     QA / Tester for Web & Software   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             38             5              0                  0.0                 1.0                      0.13              29
# 3  636884.0  sql server, scrum, javascript, english, mvc, h...                Test Automation Architect/Developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             31             5              0                  0.0                 1.0                      0.16              38
# 4  636969.0  azure, sql, javascript, english, testing, html...                           Automation Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             25             5              0                  0.0                 1.0                      0.20              17

# %%
cols = set(features) - set(['hired'])
df_pred['pred'] = gbm.predict(df_pred[cols])
df_pred = df_pred.sort_values(by='pred',ascending=False)
df_pred.head(10)

df_pred['pred'].plot.hist()
plt.show()

print(df_pred['pred'].value_counts())

#df_pred = df_pred[['usersposition','jobsposition','pred']]
df_pred
# Out:
# 0.549834    73
# 0.540818    41
# 0.508064     5
# Name: pred, dtype: int64
#        userid                                         userskills                                      usersposition  jobid                                jobresponsibilities             jobsposition                        jobskills  userskills_no  jobskills_no  common_skills  common_skills_ratio  other_skills_ratio  job_candiate_skill_ratio  position_match      pred
# 0    553625.0   ruby on rails, javascript, docker, vue.js, linux  Software Engineer · Web Expert · Automated Tes...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              5             5              1                  0.2                0.80                      1.00              35  0.549834
# 71   669574.0  sql, sql server, testing, soap, windows, jira,...          Manual Tester with 8 years of experience    3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             14             5              0                  0.0                1.00                      0.36              29  0.549834
# 85   674510.0  sql, scrum, testing, json, soap, github, test ...    Senior Test Automation Engineer/QA Engineer, BA   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             29             5              0                  0.0                1.00                      0.17              23  0.549834
# 84   674347.0  english, research, digital, social media, apac...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             28             5              0                  0.0                1.00                      0.18              27  0.549834
# 83   674105.0                                   embedded systems                             Embedded Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              1             5              0                  0.0                1.00                      5.00              36  0.549834
# 82   672841.0  soap, jmeter, sql server - intermediate, selen...    About 8 years of experience in Software Testing   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              6             5              0                  0.0                1.00                      0.83              29  0.549834
# 79   672140.0  sql, ios, jenkins, agile methodologies, sql an...                 QA Specialist (Testing Automation)   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             16             5              1                  0.2                0.94                      0.31              47  0.549834
# 75   670478.0  tdd, github, jenkins, selenium, cucumber, prot...                          QA Test Automation Expert   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              0                  0.0                1.00                      0.45              33  0.549834
# 74   670263.0  branding, itil, jira, unix, data integration -...         Associate - Project Manager / Test Manager   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             29             5              0                  0.0                1.00                      0.17              23  0.549834
# 73   670254.0  sql, testing, node.js, junit, docker, jira, re...                             Test Lead (Automation)   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             19             5              0                  0.0                1.00                      0.26              28  0.549834
# 72   670237.0  sql, scrum, javascript, iphone development, te...                       Test Lead - Software Testing   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             29             5              0                  0.0                1.00                      0.17              29  0.549834
# 70   669441.0  android, jira, user stories, quality assurance...                      Software Tester - QA engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             13             5              1                  0.2                0.92                      0.38              24  0.549834
# 47   662475.0  javascript, wordpress, html5, bootstrap, css3,...                   FrontEnd Developer and QA Tester   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              0                  0.0                1.00                      0.62              40  0.549834
# 67   668424.0  sql, maven, jira, jenkins, rest api, quality a...          Software Development Engineer in Testing    3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              32  0.549834
# 64   668140.0  javascript, node.js, docker, react.js, gulp, r...   Full stack dev with exp in React, NodeJS and PHP   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             16             5              0                  0.0                1.00                      0.31              37  0.549834
# 61   667618.0  android, instrumentation., digital, sun certif...                     QA Lead / Senior Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             23             5              0                  0.0                1.00                      0.22              35  0.549834
# 60   666966.0  sql, javascript, python, c++, css, agile metho...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             18             5              1                  0.2                0.94                      0.28              27  0.549834
# 1    614275.0  javascript, testing, node.js, jmeter, selenium...                           Specialized in QA & Test   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              0                  0.0                1.00                      0.45              53  0.549834
# 58   666357.0  android, testing, node.js, mongodb, game devel...                       NodeJS and Android Developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             10             5              0                  0.0                1.00                      0.50              39  0.549834
# 56   666006.0  javascript, python, c++, microsoft office, win...                        QA Automated Test Developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             21             5              2                  0.4                0.90                      0.24              48  0.549834
# 55   665763.0  hardware, six sigma, automation, software engi...                          Product / Business / Test   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             14             5              0                  0.0                1.00                      0.36              36  0.549834
# 53   665031.0  testing, agile methodologies, quality assuranc...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              27  0.549834
# 87   675045.0  sql server, javascript, wordpress, laravel, ze...  Test Enginner, Software Engineer, Web develope...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             63             5              0                  0.0                1.00                      0.08              31  0.549834
# 88   675296.0  android, sql server, javascript, python, testi...                        Senior QA automation Tester   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             53             5              2                  0.4                0.96                      0.09              32  0.549834
# 90   675823.0  crm, jira, databases, webdesign, data integrat...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             19             5              0                  0.0                1.00                      0.26              27  0.549834
# 91   675862.0  javascript, c++, html5, css3, my sql, perl, ma...              Software Development Engineer in Test   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              1                  0.2                0.91                      0.45              33  0.549834
# 117  682038.0  testing, test planning and test script, jira, ...                                Senior Test Manager   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             37             5              1                  0.2                0.97                      0.14              33  0.549834
# 111  679896.0  javascript, python, english, html, css, mongod...     Fullstack Developer (React + Python or NodeJS)   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             17             5              1                  0.2                0.94                      0.29              28  0.549834
# 109  679394.0  sql, scrum, unix, jmeter, quality assurance, m...          Software Tester/QA Engineer/Mentor/Leader   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             18             5              0                  0.0                1.00                      0.28              28  0.549834
# 108  678943.0  scrum, agile, jira, rest api, quality assuranc...  Software Test Engineer,  looking for overseas ...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             13             5              0                  0.0                1.00                      0.38              31  0.549834
# 107  678877.0  ruby on rails, microsoft office, hardware, lea...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             33             5              1                  0.2                0.97                      0.15              27  0.549834
# 106  678762.0                 quality assurance, support analyst   QA Software Tester with Internacional Experience   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              2             5              0                  0.0                1.00                      2.50              25  0.549834
# 104  678309.0  sql, javascript, python, laravel, mvc, html, p...      FullStack Web Developer - PHP, Python, NodeJS   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             24             5              1                  0.2                0.96                      0.21              28  0.549834
# 103  678092.0  sql server, 3d studio max html5, peoplesoft, e...                                       Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             20             5              0                  0.0                1.00                      0.25              23  0.549834
# 102  678077.0  javascript, python, html5, node.js, open sourc...                   Express/NodeJS backend developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              2                  0.4                0.78                      0.56              44  0.549834
# 101  678015.0  javascript, python, testing, html5, css3, node...              Software Development Engineer in Test   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              1                  0.2                0.91                      0.45              33  0.549834
# 100  677423.0  sql, sql server, scrum, uml, c, testing, soap,...  Test Leader, Quality's Analyst and System's An...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             18             5              0                  0.0                1.00                      0.28              28  0.549834
# 99   677240.0  test planning and test script, jmeter, seleniu...             ISTQB Certified Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              0                  0.0                1.00                      0.62              26  0.549834
# 98   677210.0  javascript, node.js, xml, itil, junit, docker,...             Software QA & Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             25             5              0                  0.0                1.00                      0.20              24  0.549834
# 97   676774.0  web services, test planning and test script, s...             Test Automation Engineering Specialist   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              43  0.549834
# 96   676717.0  scrum, javascript, testing, json, agile, groov...                                   QA Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             33             5              0                  0.0                1.00                      0.15              26  0.549834
# 95   676373.0  sql, python, testing, hibernate, soap, maven, ...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             14             5              1                  0.2                0.93                      0.36              27  0.549834
# 94   676335.0  sql, css3, soap, oracle db, oracle service bus...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             15             5              0                  0.0                1.00                      0.33              27  0.549834
# 93   676292.0  test planning and test script, quality assuran...             Software Quality Assurance And Testing   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              4             5              0                  0.0                1.00                      1.25              33  0.549834
# 92   675923.0  sql, erp, soap, junit, web services, quality a...                   Software Testing Engineer | ERP    3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              27  0.549834
# 48   662756.0                     node.js, react.js, php, jquery                             React/NodeJS developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              4             5              0                  0.0                1.00                      1.25              44  0.549834
# 59   666926.0  sql, sql server, javascript, microsoft office,...  A Software Testing and Quality Assurance Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             33             5              0                  0.0                1.00                      0.15              31  0.549834
# 27   648474.0  agile methodologies, process analysis, product...         Software Test, Process and Product Manager   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              6             5              0                  0.0                1.00                      0.83              34  0.549834
# 11   640665.0  sql, testing, html5, web development, agile, t...    Software Tester who implements end-to-end tests   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             19             5              0                  0.0                1.00                      0.26              29  0.549834
# 22   645274.0  javascript, visual basic, visual studio, agile...           Quality Assurance & Test Automation Lead   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             15             5              0                  0.0                1.00                      0.33              26  0.549834
# 25   647089.0  microsoft test manager, selenium, regression t...                    Senior Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              30  0.549834
# 21   644911.0  android, pl/sql, jira, express.js, testlink, p...                           Quality and Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              34  0.549834
# 45   659747.0  sql, scrum, testing, hibernate, node.js, junit...                  Software Automation Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             29             5              0                  0.0                1.00                      0.17              25  0.549834
# 20   643845.0  test planning and test script, jira, regressio...                             Software Test Enginner   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              0                  0.0                1.00                      0.45              27  0.549834
# 19   643772.0  android, scrum, python, uml, c++, testing, res...     QA, Test Automation, Software Testing, QA Lead   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             30             5              2                  0.4                0.93                      0.17              24  0.549834
# 29   648826.0  scrum, ios, test management, test case, bdd - ...         QA Analyst and Software Testing Specialist   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              7             5              0                  0.0                1.00                      0.71              46  0.549834
# 17   643059.0  sql server, delphi, jira, testlink, test autom...                             Software Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             10             5              1                  0.2                0.90                      0.50              27  0.549834
# 15   642855.0  sql, uml, pl/sql, excel, xml, oracle db, micro...                                       Test analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             22             5              0                  0.0                1.00                      0.23              23  0.549834
# 13   641025.0  scrum, english, testing, agile project managem...            PMP, SFC, IT Project Mgmt, Testing & QA   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             17             5              0                  0.0                1.00                      0.29              28  0.549834
# 32   649220.0  subversion, test planning and test script, jir...                     Software Testing Professional.   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              0                  0.0                1.00                      0.45              27  0.549834
# 33   649683.0  python, spring, docker, selenium, test automat...                      Back-end developer and Tester   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              6             5              0                  0.0                1.00                      0.83              38  0.549834
# 35   650844.0  javascript, node.js, c#, backend development, php                      JavaScript (NodeJS) Developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              5             5              0                  0.0                1.00                      1.00              36  0.549834
# 36   653291.0  python, testing, jenkins, rest api, quality as...                          Software Engineer in Test   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              25  0.549834
# 24   646304.0  crm, asp, jboss, junit, apache, iis, subversio...  INDIA as Principal Quality Engineer(Technical ...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             38             5              1                  0.2                0.97                      0.13              27  0.549834
# 2    634713.0  c, testing, web development, css3, google anal...                     QA / Tester for Web & Software   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             38             5              0                  0.0                1.00                      0.13              29  0.549834
# 6    637765.0  javascript, node.js, mongodb, cordova, phonega...               Frontend - Mobile - REST Full NodeJS   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              36  0.549834
# 38   657115.0  javascript, html5, bootstrap, node.js, materia...                        NodeJS Full-Stack Developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             27             5              0                  0.0                1.00                      0.19              36  0.549834
# 44   659690.0  sql, sql server, scrum, uml, testing, pl/sql, ...                                       Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             22             5              1                  0.2                0.95                      0.23              23  0.549834
# 39   657498.0  scrum, testing, ireport, junit, software devel...                    Detail-oriented QA Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             18             5              0                  0.0                1.00                      0.28              30  0.549834
# 5    637318.0  android, ruby on rails, scrum, java sdk 1.5 1....                      Software Developer and Tester   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             21             5              0                  0.0                1.00                      0.24              46  0.549834
# 41   658155.0  python, test planning and test script, seleniu...                             System Test Specialist   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              5             5              0                  0.0                1.00                      1.00              44  0.549834
# 3    636884.0  sql server, scrum, javascript, english, mvc, h...                Test Automation Architect/Developer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             31             5              0                  0.0                1.00                      0.16              38  0.549834
# 43   659208.0  test planning and test script, selenium, scrum...             Software Testing Automation Specialist   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             11             5              0                  0.0                1.00                      0.45              46  0.549834
# 110  679621.0  javascript, python, laravel, html5, css3, node...  PHP/Laravel,Python/Django,JavaScript/NodeJS /R...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              1                  0.2                0.88                      0.62              22  0.540818
# 115  681500.0  android, sql, python, testing, ios, jenkins, d...                                      Test engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             20             5              1                  0.2                0.95                      0.25              22  0.540818
# 114  681008.0                      selenium, uft, manual testing                           Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              3             5              0                  0.0                1.00                      1.67              17  0.540818
# 113  680835.0  scrum, javascript, swift, soap, jira, tfs, sel...                       QA Engineer, Test Automation   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             14             5              0                  0.0                1.00                      0.36              16  0.540818
# 18   643431.0  sql, python, c, testing, jmeter, security asse...                              Software Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             22             5              2                  0.4                0.91                      0.23              18  0.540818
# 7    638136.0  javascript, unity, microsoft office, testing, ...                                       Test Manager   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              17  0.540818
# 16   643005.0  soap, junit, selenium, test automation, functi...                    Test Engineering Senior Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              6             5              0                  0.0                1.00                      0.83              15  0.540818
# 4    636969.0  azure, sql, javascript, english, testing, html...                           Automation Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             25             5              0                  0.0                1.00                      0.20              17  0.540818
# 105  678402.0  automation, selenium, hp quality center, manua...  Automation Test Engineer with 4+years of Exper...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              7             5              0                  0.0                1.00                      0.71              22  0.540818
# 12   640871.0  testing, visual studio, jira, quality assuranc...                        Test Analyst (Coordination)   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             17             5              0                  0.0                1.00                      0.29              17  0.540818
# 10   639469.0  sql, c++, testing, automation, jira, esxi vmwa...                  Senior Test Analyst and Team Lead   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             18             5              0                  0.0                1.00                      0.28              14  0.540818
# 89   675441.0  testing, agile, jira, alm, selenium, express.j...                            Automation Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              17  0.540818
# 9    639431.0  ddd, sql server, scrum, javascript, mvc, html5...                          Test Automation  Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             21             5              0                  0.0                1.00                      0.24              17  0.540818
# 8    638520.0  sql, test planning and test script, integratio...                                    QA Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              21  0.540818
# 14   641947.0  scrum, agile methodologies, quality assurance,...                                      Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              6             5              0                  0.0                1.00                      0.83              22  0.540818
# 46   661677.0  sql, test planning and test script, selenium, ...                              Software Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              5             5              0                  0.0                1.00                      1.00              18  0.540818
# 23   645342.0  sql, scrum, python, json, xml, visual studio, ...                           Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             30             5              1                  0.2                0.97                      0.17              17  0.540818
# 50   664067.0  android, sql, python, c, english, ios, soap, t...                        QA Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             27             5              1                  0.2                0.96                      0.19              16  0.540818
# 49   663032.0  sql, javascript, python, testing, html5, soap,...  ISTQB Certified Tester (Manual / automation te...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             23             5              1                  0.2                0.96                      0.22              17  0.540818
# 54   665435.0  sql server, python, testing, xml, jira, unix, ...  QA Testing experience with 11 years of experience   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             17             5              1                  0.2                0.94                      0.29              22  0.540818
# 42   658706.0  software development, data analysis, data migr...   Performance  And Automation Test, Data Analysis    3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              5             5              0                  0.0                1.00                      1.00              15  0.540818
# 57   666314.0  testing, test planning and test script, alm, e...                                      Test Manager    3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              17  0.540818
# 40   657783.0  testing, soap, automation, test planning and t...                        QA Test/Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             17             5              0                  0.0                1.00                      0.29              16  0.540818
# 62   667781.0                                  business analysis                  Test Manager and Business Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              1             5              0                  0.0                1.00                      5.00              14  0.540818
# 63   667832.0  sql, scrum, microsoft office, testing, crm, te...          Software Test Engineer with 5.2yrs of exp   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             34             5              0                  0.0                1.00                      0.15              22  0.540818
# 37   654052.0  unix, front end, ibm rational clear case, 70-4...          Analyst Tester | Test Leader at Accenture   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              7             5              0                  0.0                1.00                      0.71              19  0.540818
# 86   674549.0  sql, web services, test planning and test scri...                    Test Engineering Senior Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             13             5              0                  0.0                1.00                      0.38              15  0.540818
# 66   668417.0  quality assurance, selenium, leadership, cucum...                            Automation Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              0                  0.0                1.00                      0.62              17  0.540818
# 68   668537.0  test planning and test script, selenium, uft, ...                           Automation Test Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              17  0.540818
# 69   669335.0  testing, github, selenium, cucumber, automatio...                           Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              0                  0.0                1.00                      0.62              17  0.540818
# 34   649693.0  scrum, testing, jira, alm, selenium, usability...                          Test Analyst \ QA Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             15             5              0                  0.0                1.00                      0.33              17  0.540818
# 31   649130.0  sql, test planning and test script, business a...                               Function Tester + BA   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              0                  0.0                1.00                      0.62              20  0.540818
# 30   648831.0  sql, sql server, uml, testing, html5, xml, tes...                              Software Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             33             5              0                  0.0                1.00                      0.15              18  0.540818
# 76   670691.0  sql, javascript, python, json, postgresql, res...                                    QA Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             52             5              2                  0.4                0.96                      0.10              21  0.540818
# 77   671410.0  maven, groovy, jenkins, rest api, selenium, sp...                           Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              17  0.540818
# 78   671498.0  c, testing, postgresql, trello, selenium, test...                                    Software Tester   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              9             5              0                  0.0                1.00                      0.56              21  0.540818
# 80   672353.0  ruby on rails, laravel, node.js, mongodb, my s...      Fullstack (NodeJS,React,laravel,AWS) Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              7             5              0                  0.0                1.00                      0.71              21  0.540818
# 81   672707.0  sql, test planning and test script, jira, alm,...                                Senior Test Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             14             5              0                  0.0                1.00                      0.36              19  0.540818
# 28   648743.0  sql, python, c, c++, test planning and test sc...                                       Test Manager   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             13             5              1                  0.2                0.92                      0.38              17  0.540818
# 26   648249.0  python, testing, html5, junit, jira, rest api,...                           Test Automation Engineer   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             12             5              0                  0.0                1.00                      0.42              17  0.540818
# 51   664811.0  sql server, delphi, itil, oracle application-p...  Test Leader with 10 years of experience in Sof...   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             16             5              0                  0.0                1.00                      0.31              22  0.540818
# 116  681818.0                                  automated testing            Test Automation Engineering Analyst-IT    3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              1             5              0                  0.0                1.00                      5.00              13  0.508064
# 65   668252.0  python, testing, agile methodologies, selenium...    QA Analyst|Test Engineer(Manual and Automation)   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              8             5              0                  0.0                1.00                      0.62              12  0.508064
# 52   664875.0       databases, quality assurance, selenium, java          Software Testing/QA Automation Sr Analyst   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              4             5              0                  0.0                1.00                      1.25              12  0.508064
# 112  680616.0  iptables firewall, linux sysadmin, portuguese,...  Information Security Analyst - Penetration Tester   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python             14             5              0                  0.0                1.00                      0.36              11  0.508064
# 118       NaN                                                NaN                                                NaN   3004  <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&...  Cloud DevOps Specialist  aws, jboss, linux, perl, python              1             5              0                  0.0                1.00                      5.00               8  0.508064
